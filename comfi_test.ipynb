# %% [markdown]
# # Computational Finance — Lab Assignment 1
# **Yara Berkelmans — 14639491**
# **Max van Beusekom — 13979345**
# **Marcos Penedo — 16523202**
#
# This assignment studies volatility estimation, implied volatility, VIX construction and delta hedging using both historical financial data and real SPX option data.
#
# The assignment consists of three main parts:
#
# 1. **Financial Data Science: Realized Volatility**
#    - Estimation of drift and volatility under the physical measure.
#    - Comparison of realized and implied volatility measures.
#
# 2. **Hedging: Volatility Mismatch**
#    - Simulation of delta hedging under correct and misspecified volatility.
#    - Analysis of hedging performance and model risk.
#
# 3. **Hedging with Real SPX Option Data**
#    - Construction of a daily NSS risk-free curve and extraction of zero rates $r_t(\tau)$.
#    - Implementation and evaluation of one-step delta hedging using SSE and Gain metrics.

# %%
# all imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# ## 2 – Hedging: Volatility Mismatch
#
# In this part of the assignment the performance of discrete-time delta hedging of a short European call is implmemented under two scenarios.
#
# The stock price paths are simulated following a Geometric Brownian Motion:
#
# $$
# dS_t = r S_t\, dt + \sigma_{\mathrm{real}} S_t\, dW_t
# $$
#
# The hedging performance will be evaluated for different heding frequencies and with a delta computed using a varying volatility parameter $\sigma_{\Delta}$.
#
# ### 2.1 Matching Volatility
# The true volatility used in the stock simulation equals the volatility used in delta computation:
# $$
# \sigma_{\mathrm{real}} = \sigma_{\Delta} = 0.20.
# $$
#
# ### 2.2 Volatility Mismatch
# The stock is simulated with:
# $$
# \sigma_{\mathrm{real}} = 0.20,
# $$
# but the delta is computed using:
# $$
# \sigma_{\Delta} \in \{0.10,\,0.15,\,0.25,\,0.30\}.
# $$

# %%
def bs_call_price(S, K, r, sigma, tau):
    """
    Calculate and return the Black-Scholes price of a European call option. 
    """
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    d2 = (np.log(S / K) + (r - 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    return S * norm.cdf(d1) - K * np.exp(-r * tau) * norm.cdf(d2)

def bs_delta_call(S, K, r, sigma, tau):
    """
    Calculate and return the Black-Scholes delta of a European call option.
    """
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    return norm.cdf(d1)


def simulate_gbm_path(S0, r, sigma_real, T, n_steps, rng):
    """
    Simulate and return stock price path following a Geometric Brownian Motion
    """
    dt = T / n_steps
    t = np.linspace(0.0, T, n_steps + 1)
    dW = np.sqrt(dt) * rng.standard_normal(n_steps)

    # Brownian motion path 
    W = np.zeros(n_steps + 1)
    W[1:] = np.cumsum(dW)

    # Drift term
    drift = (r - 0.5 * sigma_real**2) * t

    # Explicit GBM solution
    S = S0 * np.exp(drift + sigma_real * W)

    return S
    
def hedge_short_call_one_path(S_path, K, r, sigma_delta, T, hedge_every_steps):
    """
    Perform discrete-time delta hedging of a short European call option along a simulated stock price path. 
    Return final hedging Profit & Loss.   
    """
    n_steps = len(S_path) - 1
    dt = T / n_steps

    # t=0: sell call & buy delta shares
    C0 = bs_call_price(S_path[0], K, r, sigma_delta, T)
    delta = bs_delta_call(S_path[0], K, r, sigma_delta, T)
    shares = delta
    cash = C0 - shares * S_path[0]

    for i in range(n_steps):
        cash *= np.exp(r * dt)
        S_next = S_path[i+1]
        tau_next = max(T - (i+1) * dt, 0.0)

        if (i + 1) % hedge_every_steps == 0 and tau_next > 0:
            new_delta = bs_delta_call(S_next, K, r, sigma_delta, tau_next)
            cash -= (new_delta - shares) * S_next
            shares = new_delta

    S_T = S_path[-1]
    payoff = max(S_T - K, 0.0)
    portfolio_T = shares * S_T + cash
    return portfolio_T - payoff


def run_hedge_experiment(
    sigma_real,
    sigma_delta,
    hedge_freqs=(1, 2, 5),
    S0=100.0,
    K=99.0,
    r=0.06,
    T=1.0,
    n_steps=252,
    n_paths=5000,
    seed=42,):
    """
    Run a Monte Carlot delta-hedging experiment in order to solve task 1 & task 2.
    Returns summary statistics in a DataFrame. 
    """
    rng = np.random.default_rng(seed)
    all_results = {}

    for freq in hedge_freqs:
        pnls = np.empty(n_paths)
        for p in range(n_paths):
            S_path = simulate_gbm_path(S0, r, sigma_real, T, n_steps, rng)
            pnls[p] = hedge_short_call_one_path(S_path, K, r, sigma_delta, T, freq)
        all_results[freq] = pnls

    # summary statistics 
    rows = []
    for freq in hedge_freqs:
        pnls = all_results[freq]
        rows.append({
            "sigma_real": sigma_real,
            "sigma_delta": sigma_delta,
            "hedge_every_days": freq,
            "mean_pnl": pnls.mean(),
            "std_pnl": pnls.std(ddof=1),
        })
    summary_df = pd.DataFrame(rows).sort_values(["hedge_every_days"])
    return all_results, summary_df

# Task 1
task1_results, task1_summary = run_hedge_experiment(
    sigma_real=0.20,
    sigma_delta=0.20,
    hedge_freqs=(1, 2, 5),
    n_paths=3000,   
    seed=1,
)
print("\ntask 1 summary:")
print(task1_summary.to_string(index=False))

# Task 2
sigma_delta_grid = [0.10, 0.15, 0.20, 0.25, 0.30] 
sigma_real_fixed = 0.20

# hedge daily, twice a week, weekly 
hedge_freqs = (1, 2, 5)

task2_summaries = []
for sigma_delta in sigma_delta_grid:
    results, summary = run_hedge_experiment(
        sigma_real=sigma_real_fixed,
        sigma_delta=sigma_delta,
        hedge_freqs=(1,2,5),
        n_paths=3000,
        seed=1
    )
    task2_summaries.append(summary)

task2_summary = pd.concat(task2_summaries, ignore_index=True)
print("\ntask 2 summary")
print(task2_summary.to_string(index=False))
# Out:
# task 1 summary:
#  sigma_real  sigma_delta  hedge_every_days  mean_pnl  std_pnl
#         0.2          0.2                 1  0.009248 0.429580
#         0.2          0.2                 2  0.005609 0.596369
#         0.2          0.2                 5  0.030772 0.926771
#
# task 2 summary
#  sigma_real  sigma_delta  hedge_every_days  mean_pnl  std_pnl
#         0.2         0.10                 1 -3.571205 2.095723
#         0.2         0.10                 2 -3.553886 2.154404
#         0.2         0.10                 5 -3.561096 2.214156
#         0.2         0.15                 1 -1.849459 0.965016
#         0.2         0.15                 2 -1.853284 1.071150
#         0.2         0.15                 5 -1.843516 1.244958
#         0.2         0.20                 1  0.009248 0.429580
#         0.2         0.20                 2  0.005609 0.596369
#         0.2         0.20                 5  0.030772 0.926771
#         0.2         0.25                 1  1.928739 0.798826
# ...

# %%
def plot_error_PnL(task2_summary):
    plt.figure()

    for sigma in sorted(task2_summary["sigma_delta"].unique()):
        sub = task2_summary[task2_summary["sigma_delta"] == sigma]
        plt.plot(
            sub["hedge_every_days"],
            sub["std_pnl"],
            marker="o",
            linewidth=2,
            label=f"σΔ = {sigma:.2f}"
        )

    plt.xlabel("Hedge frequency (days)")
    plt.ylabel("Std of final P&L")
    plt.title("Hedging Error vs Frequency")
    plt.legend(title="Model volatility")
    plt.grid(True)
    plt.show()

plot_error_PnL(task2_summary)

def plot_mean_PnL(task2_summary):
    plt.figure()

    for sigma in sorted(task2_summary["sigma_delta"].unique()):
        sub = task2_summary[task2_summary["sigma_delta"] == sigma]

        plt.plot(
            sub["hedge_every_days"],
            sub["mean_pnl"],
            marker="o",
            linewidth=2,
            label=f"σΔ = {sigma:.2f}"
        )

    plt.xlabel("Hedge frequency (days)")
    plt.ylabel("Mean of final P&L")
    plt.title("Mean Hedging P&L vs Frequency")
    plt.legend(title="Model volatility")
    plt.grid(True)
    plt.show()

plot_mean_PnL(task2_summary)

# %% [markdown]
# ### Results
# Looking at the correctly matched volatility case (green line, σΔ = 0.20), the mean P&L stays close to zero for all hedge frequencies (about 0.009 for daily hedging and 0.031 for weekly hedging). This shows that delta hedging is unbiased when the volatility is specified correctly.
#
# At the same time, the risk of the strategy increases when hedging becomes less frequent. The standard deviation of final P&L rises from about 0.43 with daily hedging to about 0.93 with weekly hedging. This likely happens because the hedge position is adjusted less often, so larger price movements occur before rebalancing and thus more frequent hedging reduces this tracking error.
#
# For the mismatched volatility cases (the other colored lines), the mean P&L is no longer close to zero. When volatility is underestimated (for example: σΔ = 0.10 or 0.15), the mean P&L is negative (around −3.57 and −1.85), meaning the hedger will lose money on average. When volatility is overestimated (σΔ = 0.25 or 0.30), the mean P&L is positive (around 1.93 and 3.89), meaning the hedger will gain money on average.
#
# In both cases the error increases when hedging becomes less frequent, but a volatility mismatch mainly introduces systematic bias in the average P&L.

# %% [markdown]
# ## 3 - Hedging with Real SPX Option Data
#
# In this section we move from simulated data to real SPX option data.
# The objective is to implement a delta-hedging strategy using market data and a data-driven risk-free curve.
#
# We proceed in three steps:
#
# 1. Construct a daily risk-free term structure using the Nelson–Siegel–Svensson (NSS) model.
# 2. Convert Treasury yields into continuously compounded zero rates.
# 3. Apply a one-step delta-hedging strategy to real option observations and evaluate performance.

# %%
# step 1 

# load dataset
df = pd.read_csv("option20230201_20230228.csv")

print("Initial rows:", len(df))

# keep calls only 
df = df[df["cp_flag"] == "C"].copy()
print("After keeping calls:", len(df))

# convert date columns
df["date"] = pd.to_datetime(df["date"])
df["exdate"] = pd.to_datetime(df["exdate"])

# rescale strike 
df["strike"] = df["strike_price"] / 1000

# construct midquote 
df["V"] = (df["best_bid"] + df["best_offer"]) / 2

# remove missing implied volatility cells 
df = df.dropna(subset=["impl_volatility"])

print("After removing missing IV:", len(df))

# usefull for reporting 
final_columns = [
    col for col in df.columns
    if col in ["date", "exdate", "symbol", "strike", "V", "impl_volatility", "delta"]
]
df = df[final_columns]
print("Number of unique trading dates:", df["date"].nunique())
print("Number of unique expiries:", df["exdate"].nunique())
print("\nMissing rates:")
print(df[["V", "impl_volatility", "delta"]].isna().mean())
print("\nFinal columns kept:")
print(df.columns.tolist())
# Out:
# Initial rows: 175301
# After keeping calls: 175301
# After removing missing IV: 153728
# Number of unique trading dates: 19
# Number of unique expiries: 67
#
# Missing rates:
# V                  0.0
# impl_volatility    0.0
# delta              0.0
# dtype: float64
#
# Final columns kept:
# ['date', 'symbol', 'exdate', 'impl_volatility', 'delta', 'strike', 'V']

# %% [markdown]
# ### Results
#
# The raw option panel contains 175,301 observations. After filtering to calls only the sample size remains 175,301 and after removing observations with missing implied volatility, it decreases to 153,728.
# This could mean that the dataset already contained only call options, so the 'keep calls only' filter did not remove anything...
#
# The cleaned panel has 19 unique trading dates and 67 unique expiries. After preprocessing, the missing rates are 0.0 for the midquote $V_t$ as well as for market implied volatility $\sigma_{\text{mkt}}$, and delta $\delta$.
#
# The final set of variables retained for the project is: `date`, `symbol`, `exdate`, `impl_volatility`, `delta`, `strike`, and `V`.

# %%
# step 2 

# sort so shifting will work correctly within each contract
df = df.sort_values(["symbol", "date"]).copy()

# compute one-day option change within each contract 
df["dV"] = df.groupby("symbol")["V"].diff(1)

# only keep observations where ΔV_t is defined 
before_rows = len(df)
df = df.dropna(subset=["dV"]).copy()
after_rows = len(df)

# report how many contracts remain 
contracts_before = df["symbol"].nunique() 

# usefull for reporting 
print(f"Rows before computing ΔV (sorted): {before_rows}")
print(f"Rows after keeping defined ΔV:      {after_rows}")
print(f"Number of contracts retained:       {contracts_before}")

# summary statistics of V_t and ΔV_t
summary_V = df["V"].describe(percentiles=[0.01, 0.05, 0.50, 0.95, 0.99])
summary_dV = df["dV"].describe(percentiles=[0.01, 0.05, 0.50, 0.95, 0.99])

print("\nSummary stats of V:")
print(summary_V)

print("\nSummary stats of ΔV:")
print(summary_dV)
# Out:
# Rows before computing ΔV (sorted): 153728
# Rows after keeping defined ΔV:      141619
# Number of contracts retained:       11593
#
# Summary stats of V:
# count    141619.000000
# mean        424.438543
# std         575.665037
# min           0.025000
# 1%            0.025000
# 5%            0.075000
# 50%         199.800000
# 95%        1610.120000
# 99%        2721.941000
# max        3993.700000
# Name: V, dtype: float64
#
# Summary stats of ΔV:
# count    141619.000000
# mean         -6.315655
# std          27.128320
# min        -170.300000
# 1%          -78.700000
# 5%          -48.150000
# 50%          -2.150000
# 95%          44.950000
# 99%          56.000000
# max          70.200000
# Name: dV, dtype: float64

# %% [markdown]
# ### Results
#
# After constructing the one-day changes within each contract and removing undefined observations, 11,593 contracts remain in the final panel.
#
# The summary statistics show that the midquote level $V_t$ varies substantially across options and over time. The distribution is right-skewed which means that most prices are relatively low and a smal number of options are high-priced and pull the average upward.
#
# The daily changes $\Delta V_t$ are on average close to zero, indicating no strong systematic daily trend. However, their standard deviation is sizable and the extreme values are large, which shows day-to-day volatility and occasional large price movements. This is a usefull insight on why accounting for risk in hedging strategies is important.

# %%
# step 3
def load_spx(start="2023-02-01", end="2023-03-02"):

    d1 = pd.Timestamp(start).strftime("%Y%m%d")
    d2 = pd.Timestamp(end).strftime("%Y%m%d")

    url = f"https://stooq.com/q/d/l/?s=^spx&d1={d1}&d2={d2}&i=d"
    spx = pd.read_csv(url)

    cols = {c.lower(): c for c in spx.columns}
    if "date" not in cols or "close" not in cols:
        raise ValueError(f"Stooq returned unexpected columns: {spx.columns.tolist()}")

    spx = spx.rename(columns={cols["date"]: "date", cols["close"]: "S"})
    spx["date"] = pd.to_datetime(spx["date"])
    spx = spx.sort_values("date").reset_index(drop=True)

    # compute one-day change
    spx["dS"] = spx["S"].diff()

    return spx

def plot_spx_and_dS(spx):
    plt.figure()
    plt.plot(spx["date"], spx["S"])
    plt.title("SPX Close $S_t$")
    plt.xlabel("date")
    plt.ylabel("S")
    plt.xticks(rotation=45, fontsize=8)
    plt.grid(True)
    plt.show()

    plt.figure()
    plt.plot(spx["date"], spx["dS"])
    plt.title("One-day change $\\Delta S_t$")
    plt.xlabel("date")
    plt.ylabel("ΔS")
    plt.axhline(0, linewidth=1)
    plt.xticks(rotation=45, fontsize=8)
    plt.grid(True)
    plt.show()

# run step 3
spx = load_spx(start="2023-02-01", end="2023-03-02")

# usefull for reporting 
coverage = 1 - spx["dS"].isna().mean()
print("Merge coverage:", coverage)
print("\nSummary statistics of S_t:")
print(spx["S"].describe())
print("\nSummary statistics of ΔS_t:")
print(spx["dS"].describe())

plot_spx_and_dS(spx)
# Out:
# Merge coverage: 0.9523809523809523
#
# Summary statistics of S_t:
# count      21.000000
# mean     4068.892857
# std        74.859994
# min      3951.390000
# 25%      3991.050000
# 50%      4090.410000
# 75%      4136.130000
# max      4179.760000
# Name: S, dtype: float64
#
# Summary statistics of ΔS_t:
# count    20.000000
# mean     -6.893000
# std      38.249932
# min     -81.750000
# 25%     -37.840000
# 50%      -8.805000
# 75%      14.467500
# max      60.550000
# Name: dS, dtype: float64

# %% [markdown]
# ### Results
#
# The SPX time series covers the full sample period and valid one-day changes $\Delta S_t$ can be computed for all dates except the first one. As a result, almost all option observations can be matched to a valid pair $(S_t, \Delta S_t)$,  which leads to very high merge coverage of 95.24%.
#
# The level of the index $S_t$ fluctuates between approximately 3950 and 4180 over the sample period. The plot of $S_t$ demontrates a moderate day-to-day movements and a noticeable decline toward the end of the month. Despite this downward movement the overall variation remains small relative to the index level, this indicates that the market stays within a narrow range.
#
# The daily changes $\Delta S_t$ are centered around zero, as shown in the second plot. Most observations lie roughly between −60 and +60 index points, with one larger negative movement close to −80. This confirms that short-term fluctuations can be substantial, but they are small compared to the overall level of the index. The oscillating pattern around zero reflects typical daily market volatility.

# %%
# step 4a
# option trading dates T^opt
df["date"] = pd.to_datetime(df["date"]).dt.normalize()
opt_dates = df["date"].drop_duplicates().sort_values()

# load Treasury yields
url = ("https://home.treasury.gov/resource-center/data-chart-center/interest-rates/daily-treasury-rate-archives/par-yield-curve-rates-2020-2023.csv")

tr = pd.read_csv(url)

tr["date"] = pd.to_datetime(tr["date"]).dt.normalize()
tr = tr.sort_values("date")


# only keep required tenors and map them to m in years
tenor_map = {
    "1 mo": 1/12,
    "2 mo": 2/12,
    "3 mo": 3/12,
    "6 mo": 6/12,
    "1 yr": 1,
    "2 yr": 2,
    "3 yr": 3,
    "5 yr": 5,
    "7 yr": 7,
    "10 yr": 10,
    "20 yr": 20,
    "30 yr": 30,
}

# check if treasury file uses different labels
missing = [c for c in tenor_map.keys() if c not in tr.columns]
if missing:
    raise ValueError(
        "Treasury file is missing expected tenor columns: "
        f"{missing}\nAvailable columns: {tr.columns.tolist()}"
    )

# keep date and required tenors
tr = tr[["date"] + list(tenor_map.keys())].copy()

# convert yields 
for c in tenor_map.keys():
    tr[c] = pd.to_numeric(tr[c], errors="coerce")

# rename columns to the maturity m (in years)
tr = tr.rename(columns=tenor_map)
tr = tr.set_index("date").sort_index()

# sort maturities in increasing order
tr = tr[sorted(tr.columns)]

# align to option dates 
tr_panel = tr.reindex(opt_dates)

# forward-fill
tr_panel = tr_panel.ffill()

# back-fill if needed at the very beginning
if tr_panel.isna().any(axis=None):
    tr_panel = tr_panel.bfill()

tr_panel = tr_panel / 100.0

# %%
# step 4b
def g1(tau, tau1):
    x = tau / tau1
    return (1 - np.exp(-x)) / x

def g2(tau, tau1):
    x = tau / tau1
    return g1(tau, tau1) - np.exp(-x)

def g3(tau, tau2):
    x = tau / tau2
    return (1 - np.exp(-x)) / x - np.exp(-x)

def nss_yield(tau, beta0, beta1, beta2, beta3, tau1, tau2):
    return (
        beta0
        + beta1 * g1(tau, tau1)
        + beta2 * g2(tau, tau1)
        + beta3 * g3(tau, tau2)
    )

# %%
# step 4c

def build_X(maturities, tau1, tau2):
    """
    Construct and return the NSS design matrix X. 
    """
    maturities = np.asarray(maturities, dtype=float)
    X = np.column_stack([
        np.ones_like(maturities),
        g1(maturities, tau1),
        g2(maturities, tau1),
        g3(maturities, tau2),
    ])
    return X

def ols_beta(X, y):
    """
    Compute and return OLS estimate of beta in the linear model. 
    """
    beta, residuals, rank, singular_values = np.linalg.lstsq(X, y, rcond=None)
    return beta

def sse(X, y, beta):
    """
    Compute and return the sum of squared errors. 
    """
    resid = y - X @ beta
    return float(resid @ resid)

def fit_nss(yields_by_maturity, maturities, tau_grid):
    """
    Fit the Nelson–Siegel–Svensson model for one date and return best fitted parameters. 
    """
    y = np.asarray(yields_by_maturity, dtype=float)

    best = {
        "tau1": None, "tau2": None, "beta": None, "sse": np.inf
    }

    for tau1 in tau_grid:
        for tau2 in tau_grid:
            if tau2 < tau1:   
                continue

            X = build_X(maturities, tau1, tau2)
            beta = ols_beta(X, y)
            val = sse(X, y, beta)

            if val < best["sse"]:
                best.update({"tau1": tau1, "tau2": tau2, "beta": beta, "sse": val})

    return best["tau1"], best["tau2"], best["beta"], best["sse"]

# maturities in years
mats = np.array(tr_panel.columns, dtype=float)

# yields observed at those maturities for each date
Y = tr_panel.to_numpy(dtype=float) 

tau_grid = np.array([0.25, 0.5, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0], dtype=float)

rows = []
for i, date in enumerate(tr_panel.index):
    tau1_hat, tau2_hat, beta_hat, sse_hat = fit_nss(
        yields_by_maturity=Y[i, :],
        maturities=mats,
        tau_grid=tau_grid
    )
    rows.append({
        "date": date,
        "tau1": tau1_hat,
        "tau2": tau2_hat,
        "beta0": beta_hat[0],
        "beta1": beta_hat[1],
        "beta2": beta_hat[2],
        "beta3": beta_hat[3],
        "sse": sse_hat,
    })

nss_params = pd.DataFrame(rows).set_index("date").sort_index()

# %%
# step 4d and 4e 

# ensure normalized dates
df["date"] = pd.to_datetime(df["date"]).dt.normalize()
df["exdate"] = pd.to_datetime(df["exdate"]).dt.normalize()

# Step 4d: tau in years, clamp lower bound 1/365
df["tau"] = (df["exdate"] - df["date"]).dt.days / 365.0
df["tau"] = df["tau"].clip(lower=1/365)

def fitted_yield(tau, beta0, beta1, beta2, beta3, tau1, tau2):
    return beta0 + beta1*g1(tau, tau1) + beta2*g2(tau, tau1) + beta3*g3(tau, tau2)

fitted = []
for row in df.itertuples():
    params = nss_params.loc[row.date]
    fitted.append(
        fitted_yield(row.tau,
                     params["beta0"], params["beta1"], params["beta2"], params["beta3"],
                     params["tau1"], params["tau2"])
    )

df["y_hat"] = fitted

# continuous zero rate
df["r"] = 2 * np.log1p(df["y_hat"] / 2)

# discount factor
df["P"] = np.exp(-df["r"] * df["tau"])

# summary table of r_t(tau) across the option panel
r_summary = pd.Series({
    "min": df["r"].min(),
    "median": df["r"].median(),
    "max": df["r"].max(),
})
print(r_summary.to_frame(name="r_t(tau)"))

# plot fitted curve tau for a representative date
rep_date = pd.Timestamp("2023-02-28")  

# if chosen date not available, pick the closest available date in nss_params
if rep_date not in nss_params.index:
    rep_date = nss_params.index[nss_params.index.get_indexer([rep_date], method="nearest")[0]]

p = nss_params.loc[rep_date]

# grid of maturities in years for plotting
tau_grid_plot = np.linspace(1/365, 30.0, 400)

# fitted annual yield 
yhat_plot = nss_yield(
    tau_grid_plot,
    p["beta0"], p["beta1"], p["beta2"], p["beta3"],
    p["tau1"], p["tau2"]
)
r_plot = 2.0 * np.log1p(yhat_plot / 2.0)

plt.figure()
plt.plot(tau_grid_plot, r_plot)
plt.xlabel("Maturity τ (years)")
plt.ylabel("r_t(τ)")
plt.title(f"Fitted zero-rate curve r_t(τ) on {rep_date.date()}")
plt.grid(True)
plt.show()

# verification: every option row has finite r_t(tau) and P_t(tau)
finite_r = np.isfinite(df["r"]).all()
finite_P = np.isfinite(df["P"]).all()

print("\nVerification:")
print("All option rows have finite r_t(tau)?", finite_r)
print("All option rows have finite P_t(tau)?", finite_P)
# Out:
#         r_t(tau)
# min     0.034767
# median  0.046740
# max     0.050808
# Verification:
# All option rows have finite r_t(tau)? True
# All option rows have finite P_t(tau)? True
#             date              symbol     exdate  impl_volatility     delta  \
# 84363 2023-02-14  SPX 230217C2300000 2023-02-17         2.412277  0.999558
# 84364 2023-02-14  SPX 230217C2350000 2023-02-17         2.300530  0.999595
# 84365 2023-02-14  SPX 230217C2400000 2023-02-17         2.188078  0.999637
# 84366 2023-02-14  SPX 230217C2450000 2023-02-17         2.073432  0.999683
# 84367 2023-02-14  SPX 230217C2500000 2023-02-17         2.181280  0.999237
#
#        strike       V     dV       tau     y_hat         r         P
# 84363  2300.0  1836.4 -30.10  0.008219  0.044635  0.044144  0.999637
# 84364  2350.0  1786.4 -30.05  0.008219  0.044635  0.044144  0.999637
# 84365  2400.0  1736.4 -30.15  0.008219  0.044635  0.044144  0.999637
# ...

# %% [markdown]
# ### Results
#
# For each option trading date a Nelson–Siegel–Svensson (NSS) curve is fitted to the observed Treasury yields $y_t(\tau)$ across different maturities. These fitted yields are then converted into continuously-compounded zero rates $r_t(\tau)$, which are used to discount future payoffs and to compute forward prices in the hedging analysis.
#
# Over the full option panel, the zero rates range from 3.48% to 5.08%, with a median of 4.67%. This suggests a slightly upward-sloping term structure during the sample period. The fitted curve on 2023-02-28 is smooth and realistic, showing some curvature at short maturities and gradually flattening for longer maturities.
#
# All option observations have finite values for $r_t(\tau)$ and for the discount factor $P_t(\tau)$. This means the zero-rate curve is well-defined and can be safely used in the following hedging calculations.

# %%
# 5a) Baseline delta
if "delta" in df.columns:
    df["delta_bs"] = pd.to_numeric(df["delta"], errors="coerce")
else:
    S = pd.to_numeric(df["S"], errors="coerce").to_numpy()
    K = pd.to_numeric(df["strike"], errors="coerce").to_numpy()
    tau = pd.to_numeric(df["tau"], errors="coerce").to_numpy()
    sigma = pd.to_numeric(df["impl_volatility"], errors="coerce").to_numpy()
    r = (pd.to_numeric(df["r"], errors="coerce").fillna(0.0).to_numpy()
        if "r" in df.columns else np.zeros(len(df), dtype=float))

    tau = np.maximum(tau, 1/365)
    sigma = np.maximum(sigma, 1e-12)

    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    df["delta_bs"] = norm.cdf(d1)

# 5b) Merge SPX and compute hedging residuals
df["date"] = pd.to_datetime(df["date"]).dt.normalize()
spx["date"] = pd.to_datetime(spx["date"]).dt.normalize()

spx = spx.sort_values("date").drop_duplicates(subset=["date"], keep="last")

df = df.drop(columns=[c for c in ["S", "dS"] if c in df.columns])
df = df.merge(spx[["date", "S", "dS"]], on="date", how="left", validate="m:1")


df = df.sort_values(["symbol", "date"]).copy()
df["delta_lag"] = df.groupby("symbol")["delta_bs"].shift(1)
df["eps_bs"] = df["dV"] - df["delta_lag"] * df["dS"]

# compute residuals for vendor provided delta to compare against bs calculated residuals
df["given_delta_lag"] = df.groupby("symbol")["delta"].shift(1)
df['eps_vendor'] = df['dV'] - (df["given_delta_lag"] * df['dS'])

df_eps = df.dropna(subset=["eps_bs"]).copy()

print(df_eps["eps_bs"].describe(percentiles=[0.01, 0.05, 0.50, 0.95, 0.99]))
print(float((df_eps["eps_bs"] ** 2).sum()))
print(df["delta_bs"].isna().mean())
print(df["delta_bs"].describe(percentiles=[0.01, 0.05, 0.50, 0.95, 0.99]))
# Out:
# count    130026.000000
# mean         -0.310760
# std           7.395222
# min        -170.197943
# 1%          -24.702747
# 5%           -5.697730
# 50%          -0.073311
# 95%           6.172611
# 99%          17.447837
# max         101.020060
# Name: eps_bs, dtype: float64
# 7123533.663956452
# 0.0
# count    141619.000000
# mean          0.588037
# std           0.354327
# min           0.000141
# 1%            0.000305
# 5%            0.001426
# 50%           0.696665
# 95%           0.989945
# 99%           0.998118
# max           0.999997
# Name: delta_bs, dtype: float64

# %%
# 5b) Merge SPX and compute hedging residuals
df["date"] = pd.to_datetime(df["date"]).dt.normalize()
spx["date"] = pd.to_datetime(spx["date"]).dt.normalize()

spx = spx.sort_values("date").drop_duplicates(subset=["date"], keep="last")

df = df.drop(columns=[c for c in ["S", "dS"] if c in df.columns])
df = df.merge(spx[["date", "S", "dS"]], on="date", how="left", validate="m:1")

df = df.sort_values(["symbol", "date"]).copy()
df["delta_lag"] = df.groupby("symbol")["delta_bs"].shift(1)
df["eps_bs"] = df["dV"] - df["delta_lag"] * df["dS"]

df_eps = df.dropna(subset=["eps_bs"]).copy()

print(df_eps["eps_bs"].describe(percentiles=[0.01, 0.05, 0.50, 0.95, 0.99]))
print(float((df_eps["eps_bs"] ** 2).sum()))
# Out:
# count    130026.000000
# mean         -0.310760
# std           7.395222
# min        -170.197943
# 1%          -24.702747
# 5%           -5.697730
# 50%          -0.073311
# 95%           6.172611
# 99%          17.447837
# max         101.020060
# Name: eps_bs, dtype: float64
# 7123533.663956452

# %%
# 5c
# make the D_t column for filtering
print(df.head())
df["D_t"] = (pd.to_datetime(df['exdate']) - pd.to_datetime(df['date'])).dt.days

print(f'starting row count: {len(df)}')

# filter out rows with delta >= 0.05 and delta <= 0.95
standardized_df = df[(df['delta_bs'] > 0.05) & (df['delta_bs'] < 0.95)].copy()
print(f'after filtering on delta: {len(standardized_df)}')

print(f"Length of D_t <= 14: {len(standardized_df[standardized_df['D_t'] <= 14])}")

# filter out rows with days till expiry <= 14
print(standardized_df['D_t'])
standardized_df = standardized_df[standardized_df['D_t'] > 14].copy()
print(f'after filtering on days to expiry: {len(standardized_df)}')
# Out:
#         date              symbol     exdate  impl_volatility     delta  \
# 0 2023-02-14  SPX 230217C2300000 2023-02-17         2.412277  0.999558
# 1 2023-02-14  SPX 230217C2350000 2023-02-17         2.300530  0.999595
# 2 2023-02-14  SPX 230217C2400000 2023-02-17         2.188078  0.999637
# 3 2023-02-14  SPX 230217C2450000 2023-02-17         2.073432  0.999683
# 4 2023-02-14  SPX 230217C2500000 2023-02-17         2.181280  0.999237
#
#    strike       V     dV       tau     y_hat         r         P  delta_bs  \
# 0  2300.0  1836.4 -30.10  0.008219  0.044635  0.044144  0.999637  0.997400
# 1  2350.0  1786.4 -30.05  0.008219  0.044635  0.044144  0.999637  0.997574
# 2  2400.0  1736.4 -30.15  0.008219  0.044635  0.044144  0.999637  0.997778
# 3  2450.0  1686.4 -30.20  0.008219  0.044635  0.044144  0.999637  0.998023
# 4  2500.0  1636.5 -30.30  0.008219  0.044635  0.044144  0.999637  0.995935
#
#    delta_lag  eps_bs  given_delta_lag  eps_vendor        S    dS
# ...

# %%
# 5e 

# create 9 moneyness buckets based on delta
moneyness_bins = np.linspace(0.05, 0.95, 10)
standardized_df['moneyness_bucket'] = pd.cut(standardized_df['delta_bs'], bins=moneyness_bins, include_lowest=True)

# create 7 equally spaced maturity bins 
maturity_bins = np.linspace(standardized_df['D_t'].min(), standardized_df['D_t'].max(), 7)
print(maturity_bins)

standardized_df['maturity_bucket'] = pd.cut(standardized_df['D_t'], bins=maturity_bins, include_lowest=True)
print(standardized_df[['D_t', 'maturity_bucket']].head(50000))
# Out:
# [  15.  309.  603.  897. 1191. 1485. 1779.]
#        D_t  maturity_bucket
# 612     15  (14.999, 309.0]
# 620     15  (14.999, 309.0]
# 628     15  (14.999, 309.0]
# 636     15  (14.999, 309.0]
# 644     15  (14.999, 309.0]
# ...    ...              ...
# 95265   23  (14.999, 309.0]
# 95266   22  (14.999, 309.0]
# 95267   26  (14.999, 309.0]
# 95268   23  (14.999, 309.0]
# 95269   22  (14.999, 309.0]
#
# [50000 rows x 2 columns]

# %%
# 5f 

# calculate vendor sse and mse
vendor_sse = float((standardized_df["eps_vendor"] ** 2).sum())
vendor_mse = vendor_sse / len(standardized_df)

# calculate black scholes sse and mse
bs_sse = float((standardized_df["eps_bs"] ** 2).sum())
bs_mse = bs_sse / len(standardized_df)
print(f'vendor provided sse: {vendor_sse:.4f}, mse: {vendor_mse:.4f}')
print(f'bs calculated sse: {bs_sse:.4f}, mse: {bs_mse:.4f}')

# calculate gain
gain = 1 - (bs_sse / vendor_sse)
print(f'gain of bs delta over vendor delta: {gain:.2%}')
# Out:
# vendor provided sse: 887073.8662, mse: 10.5374
# bs calculated sse: 1015723.2388, mse: 12.0657
# gain of bs delta over vendor delta: -14.50%
